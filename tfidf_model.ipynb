# %%
import pyspark
from pyspark.sql.functions import col,when,size,min, max,length
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.master('local[*]').appName('topic_modelling').getOrCreate()

# %%
df_parquet = spark.read.parquet("part-00000-a8a717e8-bf83-42e3-a0b7-084971053d99-c000.snappy.parquet")

# %%
# create a column and put in the detected language code
from langdetect import detect
getCode = lambda x:detect(x)
sent = "this is eng"
getCode(sent)
# Out:
# 'en'

# %%
# create a column and put in the detected language code
from langdetect import detect
# app_name_result = df_parquet.select(col('description')).collect()
# # create udf function to add a new column
# import pyspark.sql.functions as F
# from pyspark.sql.types import *

# def detect_lang(value):
#   return detect(value)

# #convert to a UDF Function by passing in the function and return type of function
# udf_detect_lang = F.udf(detect_lang, StringType())
# df_with_code = df_parquet.withColumn('lang_code', udf_detect_lang(df_parquet.description))
# df_with_code.show(5)

# easier method to convert to pandas then apply then function
df_parquet_pd = df_parquet.toPandas()
df_parquet_pd['lang_code'] = df_parquet_pd['description'].apply(getCode)
df_parquet_pd
# Out:
#                                app_name  \
# 0             Black Box - Movie Listing
# 1                    Knife Throwing Max
# 2                                  爆料公社
# 3        Lidow - Photo Editor & Collage
# 4        Vidstitch Frames for Instagram
# ..                                  ...
# 860  Barber Hair Salon & Beard Makeover
# 861               DJ Remix Offline 2020
# 862             Sahih Bukhari (English)
# 863                  Two Minute English
# 864              Galaxy S9 purple Theme
#
#                                             bundle  \
# 0                                        958957112
# 1                                       1491396285
# 2                                       1387765782
# 3                                        894532288
# 4                                        712908978
# ..                                             ...
# 860  com.hmg.haircutgames.beardsalon.barberhaircut
# 861                    com.mpro.djremixoffline2020
# 862                   com.bangladroid.sahihbukhari
# 863                  com.astrobix.twominuteenglish
# 864                  com.thegosa.s9purplefreetheme
#
#                                            description  \
# 0    Black Box Movie Listing App is a collection li...
# 1    you will have fun in this game\n100+ challengi...
# 2    全台最大社群「爆料公社」APP 上線啦，我們把社群解放了，不只有勁爆的爆料內容，還貼心的加上...
# 3    layout/grid/collage、Square/no crop for instagr...
# 4    ■ #Vidstitch\n■ Featured on 148apps, Stelapps,...
# ..                                                 ...
# 860  Barber hair makeover salon game is for those w...
# 861  Dj Remix Offline 2020 Mp3 merupakan aplikasi m...
# 862  We have made this application from the book of...
# 863  Improve your spoken English rapidly with the h...
# 864  Now this application is a full theme for all s...
#
#                                       genres os_platform lang_code
# 0    [Entertainment, Magazines & Newspapers]         IOS        en
# 1         [Games_Sports, Games_Role Playing]         IOS        en
# 2                        [Social Networking]         IOS     zh-tw
# 3                            [Photo & Video]         IOS        en
# 4         [Photo & Video, Social Networking]         IOS        en
# ..                                       ...         ...       ...
# 860          [ENTERTAINMENT, FAMILY_PRETEND]     ANDROID        en
# 861                        [MUSIC_AND_AUDIO]     ANDROID        id
# 862                    [BOOKS_AND_REFERENCE]     ANDROID        en
# 863                              [EDUCATION]     ANDROID        en
# 864                        [PERSONALIZATION]     ANDROID        en
#
# [865 rows x 6 columns]

# %%
# load with only English data
df_parquet_en = df_parquet_pd.loc[df_parquet_pd['lang_code']=='en']
df_parquet_en.shape
# Out:
# (687, 6)

# %%
df_spark = spark.createDataFrame(df_parquet_en)

# %%
# Step 1. Text cleasing with punctuations
from pyspark.sql.functions import regexp_replace
REGEX = '[,\\-.!?@#$%^&*+/\d]'
df_spark = df_spark.withColumn("description_clean",regexp_replace(df_spark.description,REGEX,' '))
df_spark.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+--------------------+
# |            app_name|              bundle|         description|              genres|os_platform|lang_code|   description_clean|   description_token| description_no_stop|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+--------------------+
# |Black Box - Movie...|           958957112|Black Box Movie L...|[Entertainment, M...|        IOS|       en|Black Box Movie L...|[black, box, movi...|[black, box, movi...|
# |  Knife Throwing Max|          1491396285|you will have fun...|[Games_Sports, Ga...|        IOS|       en|you will have fun...|[you, will, have,...|[fun, game, 100, ...|
# |Lidow - Photo Edi...|           894532288|layout/grid/colla...|     [Photo & Video]|        IOS|       en|layout grid colla...|[layout, grid, co...|[layout, grid, co...|
# |Vidstitch Frames ...|           712908978|■ #Vidstitch
# ■ Fe...|[Photo & Video, S...|        IOS|       en|■  Vidstitch
# ■ Fe...|[■, , vidstitch, ...|[■, , vidstitch, ...|
# |Where's my Cat? -...|          1259238703|The cat is hiding...|[Entertainment, G...|        IOS|       en|The cat is hiding...|[the, cat, is, hi...|[cat, hiding, com...|
# |Martial Art Wallp...|com.martialart.wa...|Martial arts are ...|   [PERSONALIZATION]|    ANDROID|       en|Martial arts are ...|[martial, arts, a...|[martial, arts, c...|
# |      Image detector|com.saryelgmal.se...|Google image sear...|             [TOOLS]|    ANDROID|       en|Google image sear...|[google, image, s...|[google, image, s...|
# |Horoscope - Face ...|com.ocean.horosco...|Your face reveals...|         [LIFESTYLE]|    ANDROID|       en|Your face reveals...|[your, face, reve...|[face, reveals, l...|
# |Neon Pastel Heart...|com.ikeyboard.the...|💌
# Neon Pastel He...|   [PERSONALIZATION]|    ANDROID|       en|💌
# Neon Pastel He...|[💌, neon, pastel...|[💌, neon, pastel...|
# |Arabic Voice Typi...|com.worthy.apps.a...|⭕ Arabic Voice Ke...|             [TOOLS]|    ANDROID|       en|⭕ Arabic Voice Ke...|[⭕, arabic, voice...|[⭕, arabic, voice...|
# |Document Scanner ...|   com.cv.docscanner|Sometimes in a si...|      [PRODUCTIVITY]|    ANDROID|       en|Sometimes in a si...|[sometimes, in, a...|[sometimes, singl...|
# |Vob To Mp4 Video ...|    grant.vob.to.mp4|Easy to use tool ...|     [VIDEO_PLAYERS]|    ANDROID|       en|Easy to use tool ...|[easy, to, use, t...|[easy, use, tool,...|
# |satfinder, Tv Sat...|com.afnan.satfind...|Finding a TV sate...|             [TOOLS]|    ANDROID|       en|Finding a TV sate...|[finding, a, tv, ...|[finding, tv, sat...|
# |Chat with sasha &...|   com.sasha.maxchat|If you are a grea...|   [GAME_SIMULATION]|    ANDROID|       en|If you are a grea...|[if, you, are, a,...|[great, fan, “sas...|
# |             Chess 2|com.onecwireless....|Play new, easy to...|        [GAME_BOARD]|    ANDROID|       en|Play new  easy to...|[play, new, , eas...|[play, new, , eas...|
# |Merge Airplane Id...|com.pf.idleplane....|Click, merge & de...|   [GAME_SIMULATION]|    ANDROID|       en|Click  merge   de...|[click, , merge, ...|[click, , merge, ...|
# |Date-me - Free Da...|  com.dateme.android|Date-me gets you ...|            [SOCIAL]|    ANDROID|       en|Date me gets you ...|[date, me, gets, ...|[date, gets, back...|
# |Software Engineering|com.faadooenginee...|The app is a comp...|         [EDUCATION]|    ANDROID|       en|The app is a comp...|[the, app, is, a,...|[app, complete, f...|
# |Multi FB - Multi ...|multiple.accounts...|Want to login mul...|            [SOCIAL]|    ANDROID|       en|Want to login mul...|[want, to, login,...|[want, login, mul...|
# |Walktrough: Resid...|com.guideforresid...|Informations, Tip...|         [EDUCATION]|    ANDROID|       en|Informations  Tip...|[informations, , ...|[informations, , ...|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Step 2. Tokenization
# df_spark = df_spark.drop("description_token")
from pyspark.ml.feature import Tokenizer
tokenizer = Tokenizer(inputCol='description_clean',outputCol='description_token')
df_spark = tokenizer.transform(df_spark)
df_spark.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+--------------------+
# |            app_name|              bundle|         description|              genres|os_platform|lang_code|   description_clean| description_no_stop|   description_token|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+--------------------+
# |Black Box - Movie...|           958957112|Black Box Movie L...|[Entertainment, M...|        IOS|       en|Black Box Movie L...|[black, box, movi...|[black, box, movi...|
# |  Knife Throwing Max|          1491396285|you will have fun...|[Games_Sports, Ga...|        IOS|       en|you will have fun...|[fun, game, 100, ...|[you, will, have,...|
# |Lidow - Photo Edi...|           894532288|layout/grid/colla...|     [Photo & Video]|        IOS|       en|layout grid colla...|[layout, grid, co...|[layout, grid, co...|
# |Vidstitch Frames ...|           712908978|■ #Vidstitch
# ■ Fe...|[Photo & Video, S...|        IOS|       en|■  Vidstitch
# ■ Fe...|[■, , vidstitch, ...|[■, , vidstitch, ...|
# |Where's my Cat? -...|          1259238703|The cat is hiding...|[Entertainment, G...|        IOS|       en|The cat is hiding...|[cat, hiding, com...|[the, cat, is, hi...|
# |Martial Art Wallp...|com.martialart.wa...|Martial arts are ...|   [PERSONALIZATION]|    ANDROID|       en|Martial arts are ...|[martial, arts, c...|[martial, arts, a...|
# |      Image detector|com.saryelgmal.se...|Google image sear...|             [TOOLS]|    ANDROID|       en|Google image sear...|[google, image, s...|[google, image, s...|
# |Horoscope - Face ...|com.ocean.horosco...|Your face reveals...|         [LIFESTYLE]|    ANDROID|       en|Your face reveals...|[face, reveals, l...|[your, face, reve...|
# |Neon Pastel Heart...|com.ikeyboard.the...|💌
# Neon Pastel He...|   [PERSONALIZATION]|    ANDROID|       en|💌
# Neon Pastel He...|[💌, neon, pastel...|[💌, neon, pastel...|
# |Arabic Voice Typi...|com.worthy.apps.a...|⭕ Arabic Voice Ke...|             [TOOLS]|    ANDROID|       en|⭕ Arabic Voice Ke...|[⭕, arabic, voice...|[⭕, arabic, voice...|
# |Document Scanner ...|   com.cv.docscanner|Sometimes in a si...|      [PRODUCTIVITY]|    ANDROID|       en|Sometimes in a si...|[sometimes, singl...|[sometimes, in, a...|
# |Vob To Mp4 Video ...|    grant.vob.to.mp4|Easy to use tool ...|     [VIDEO_PLAYERS]|    ANDROID|       en|Easy to use tool ...|[easy, use, tool,...|[easy, to, use, t...|
# |satfinder, Tv Sat...|com.afnan.satfind...|Finding a TV sate...|             [TOOLS]|    ANDROID|       en|Finding a TV sate...|[finding, tv, sat...|[finding, a, tv, ...|
# |Chat with sasha &...|   com.sasha.maxchat|If you are a grea...|   [GAME_SIMULATION]|    ANDROID|       en|If you are a grea...|[great, fan, “sas...|[if, you, are, a,...|
# |             Chess 2|com.onecwireless....|Play new, easy to...|        [GAME_BOARD]|    ANDROID|       en|Play new  easy to...|[play, new, , eas...|[play, new, , eas...|
# |Merge Airplane Id...|com.pf.idleplane....|Click, merge & de...|   [GAME_SIMULATION]|    ANDROID|       en|Click  merge   de...|[click, , merge, ...|[click, , merge, ...|
# |Date-me - Free Da...|  com.dateme.android|Date-me gets you ...|            [SOCIAL]|    ANDROID|       en|Date me gets you ...|[date, gets, back...|[date, me, gets, ...|
# |Software Engineering|com.faadooenginee...|The app is a comp...|         [EDUCATION]|    ANDROID|       en|The app is a comp...|[app, complete, f...|[the, app, is, a,...|
# |Multi FB - Multi ...|multiple.accounts...|Want to login mul...|            [SOCIAL]|    ANDROID|       en|Want to login mul...|[want, login, mul...|[want, to, login,...|
# |Walktrough: Resid...|com.guideforresid...|Informations, Tip...|         [EDUCATION]|    ANDROID|       en|Informations  Tip...|[informations, , ...|[informations, , ...|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Step 3. Remove stopword
# df_spark = df_spark.drop("description_no_stop")
from pyspark.ml.feature import StopWordsRemover
stopwords = StopWordsRemover(inputCol="description_token",outputCol="description_no_stop")
# stopwords.getStopWords()
df_spark = stopwords.transform(df_spark)

# %%
df_pd_desc_final = df_spark.toPandas()

# %% [markdown]
# ### Note: IDF vector must be trained with large corpus, otherwise lose the advance of IDF

# %%
# get the "description" column
joinF= lambda x:" ".join(x)
df_pd_desc_final["description_join"] = df_pd_desc_final["description_no_stop"].apply(joinF)

# %%
corpus_list = df_pd_desc_final["description_join"].tolist()

# %%
# Step 4. TF-IDF countvector, Transform documents to document-term matrix
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df=0.95) #ignore terms that have a document frequency strictly higher than the given threshold
dtm = cv.fit_transform(corpus_list)

# %%
dtm.shape
# Out:
# (687, 12089)

# %%
feature_names = cv.get_feature_names()

# %%
feature_names
# Out:
# ['_________',
#  '__________',
#  '___________________________________________',
#  '________features____',
#  '_hours',
#  '_w',
#  'aac',
#  'aagaz',
#  'aaja',
#  'aana',
#  'aap',
#  'aapake',
#  'aapko',
#  'aarti',
#  'aashiq',
#  'ab',
#  'abacus',
#  'abandon',
#  'abc',
#  'abdul',
#  'abdullah',
#  'abilities',
#  'ability',
#  'ablar',
#  'able',
#  'ablution',
#  'abnormal',
#  'aboard',
#  'aboki',
#  'about',
#  'aboutads',
#  'aboutus',
#  'above',
#  'abraxas',
#  'abreast',
#  'abridged',
#  'abroad',
#  'abs',
#  'absolute',
#  'absolutely',
#  'absorb',
#  'absorbed',
#  'absorbing',
#  'abstract',
#  'abstraction',
#  'abstracts',
#  'abu',
#  'abundant',
#  'abx',
#  'ac',
#  'academic',
#  'academy',
#  'acca',
#  'accelerate',
#  'acceleration',
#  'accelerator',
#  'accelerometer',
#  'accent',
#  'accents',
#  'accept',
#  'acceptance',
#  'accepted',
#  'access',
#  'access_coarse_location',
#  'access_fine_location',
#  'accessibility',
#  'accessible',
#  'accessing',
#  'accessories',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidently',
#  'acclaim',
#  'accolades',
#  'accompanied',
#  'accompany',
#  'accompanying',
#  'accomplish',
#  'accomplishment',
#  'accordance',
#  'according',
#  'accordingly',
#  'account',
#  'accounting',
#  'accounts',
#  'accumulate',
#  'accumulated',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'ace',
#  'aces',
#  'ach',
#  'acharya',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieves',
#  'achieving',
#  'acid',
#  'acknowledge',
#  'acknowledged',
#  'acknowledgements',
#  'acne',
#  'acoustic',
#  'acquired',
#  'acrobatic',
#  'acrobatics',
#  'across',
#  'act',
#  'action',
#  'actions',
#  'activate',
#  'activated',
#  'activates',
#  'activating',
#  'active',
#  'actively',
#  'activities',
#  'activity',
#  'actor',
#  'actors',
#  'actresses',
#  'acts',
#  'actual',
#  'actually',
#  'ad',
#  'adam',
#  'adapt',
#  'adaptable',
#  'adapted',
#  'adapter',
#  'adapters',
#  'adb',
#  'adchoices',
#  'add',
#  'added',
#  'addict',
#  'addicted',
#  'addicting',
#  'addiction',
#  'addictions',
#  'addictive',
#  'addicts',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'additions',
#  'addons',
#  'address',
#  'addresses',
#  'adds',
#  'adelaide',
#  'adequate',
#  'adha',
#  'adhd',
#  'adjacent',
#  'adjectives',
#  'adjust',
#  'adjustable',
#  'adjusted',
#  'adjusting',
#  'adjustment',
#  'adjustments',
#  'adjusts',
#  'admin',
#  'administered',
#  'administrator',
#  'administrators',
#  'admirably',
#  'admit',
#  'admitted',
#  'adopt',
#  'adopted',
#  'adorable',
#  'adore',
#  'adrenaline',
#  'ads',
#  'adult',
#  'adults',
#  'advance',
#  'advanced',
#  'advancing',
#  'advantage',
#  'advantages',
#  'adventure',
#  'adventures',
#  'adventuring',
#  'adversaries',
#  'adversely',
#  'advertise',
#  'advertisement',
#  'advertisements',
#  'advertising',
#  'advice',
#  'advices',
#  'advise',
#  'advisor',
#  'adw',
#  'aed',
#  'aerial',
#  'aero',
#  'aerobatic',
#  'aerobatics',
#  'aerodrome',
#  'aerodromes',
#  'aerodynamics',
#  'aesop',
#  'aesthetic',
#  'affairs',
#  'affect',
#  'affected',
#  'affects',
#  'affiliated',
#  'afford',
#  'afghan',
#  'afghani',
#  'afghanistan',
#  'afk',
#  'afn',
#  'afp',
#  'afraid',
#  'africa',
#  'african',
#  'after',
#  'afterbirth',
#  'age',
#  'aged',
#  'ages',
#  'aggressive',
#  'agile',
#  'agility',
#  'agitated',
#  'agmikor',
#  'agree',
#  'agreed',
#  'agreeing',
#  'agreement',
#  'agricultural',
#  'agriculture',
#  'agusta',
#  'ah',
#  'ahadeeth',
#  'ahead',
#  'ahlam',
#  'ahoy',
#  'ai',
#  'aid',
#  'aikido',
#  'aileron',
#  'ailerons',
#  'aim',
#  'aimed',
#  'aiming',
#  'aims',
#  'aiport',
#  'air',
#  'airborne',
#  'airbrush',
#  'aircraft',
#  'aircrafts',
#  'airing',
#  'airline',
#  'airpak',
#  'airplane',
#  'airplanes',
#  'airport',
#  'airports',
#  'airsim',
#  'aisle',
#  'ak',
#  'akh',
#  'akshaya',
#  'al',
#  'alafasy',
#  'alamate',
#  'alan',
#  'alarm',
#  'alarms',
#  'alaska',
#  'albanian',
#  'album',
#  'albums',
#  'alcatel',
#  'alchemy',
#  'alcoholic',
#  'ale',
#  'alert',
#  'alertness',
#  'alerts',
#  'alex',
#  'alexander',
#  'algebra',
#  'algeria',
#  'algerian',
#  'algorithm',
#  'algorithms',
#  'alictus',
#  'alien',
#  'alighnment',
#  'aligned',
#  'alignment',
#  'alike',
#  'alim',
#  'alive',
#  'all',
#  'alladvices',
#  'allah',
#  'allen',
#  'allergens',
#  'allergic',
#  'allergy',
#  'alliance',
#  'allies',
#  'allo',
#  'allotted',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'allshowdown',
#  'allways',
#  'ally',
#  'almanacs',
#  'almost',
#  'alone',
#  'along',
#  'alongside',
#  'aloud',
#  'alpha',
#  'alphabet',
#  'alphabetic',
#  'alphabetical',
#  'alphabets',
#  'already',
#  'also',
#  'alternate',
#  'alternating',
#  'alternative',
#  'although',
#  'altimeter',
#  'altitude',
#  'altruism',
#  'always',
#  'amader',
#  'amaze',
#  'amazed',
#  'amazing',
#  'amazingly',
#  'amazon',
#  'ambedkar',
#  'ambiance',
#  'ambient',
#  'ambulance',
#  'ambush',
#  'amd',
#  'amen',
#  'america',
#  'american',
#  'americos',
#  'americostech',
#  'amharic',
#  'ammo',
#  'ammunition',
#  'amoled',
#  'among',
#  'amongst',
#  'amor',
#  'amos',
#  'amount',
#  'amounts',
#  'ample',
#  'amrap',
#  'amrita',
#  'amsterdam',
#  'amuse',
#  'amusement',
#  'amusing',
#  'amzvn',
#  'an',
#  'anagram',
#  'anagrams',
#  'analog',
#  'analysis',
#  'analytics',
#  'analyze',
#  'analyzing',
#  'anantapur',
#  'anatomical',
#  'anatomy',
#  'anchor',
#  'ancient',
#  'and',
#  'andaman',
#  'anddev',
#  'andersen',
#  'andhra',
#  'andreas',
#  'andriod',
#  'android',
#  'anecdotes',
#  'ang',
#  'angel',
#  'angels',
#  'anger',
#  'angle',
#  'angles',
#  'anglicized',
#  'angling',
#  'angolan',
#  'angry',
#  'animal',
#  'animals',
#  'animate',
#  'animated',
#  'animating',
#  'animation',
#  'animations',
#  'animator',
#  'animatronics',
#  'anime',
#  'anjaam',
#  'anmol',
#  'anna',
#  'anne',
#  'anniversary',
#  'annotate',
#  'annotation',
#  'announced',
#  'announcer',
#  'announces',
#  'annoyed',
#  'annoying',
#  'annual',
#  'annually',
#  'anonymous',
#  'anonymously',
#  'another',
#  'ansaar',
#  'answer',
#  'answered',
#  'answering',
#  'answers',
#  'ant',
#  'antelope',
#  'antena',
#  'antenna',
#  'anti',
#  'antibirth',
#  'antidepressant',
#  'antillean',
#  'antiquity',
#  'antivirus',
#  'antonyms',
#  'antra',
#  'ants',
#  'anu',
#  'anxiety',
#  'any',
#  'anymore',
#  'anyone',
#  'anything',
#  'anytime',
#  'anyway',
#  'anywhere',
#  'aoa',
#  'aokp',
#  'ap',
#  'apart',
#  'apes',
#  'apex',
#  'api',
#  'apj',
#  'apk',
#  'apko',
#  'apna',
#  'apnake',
#  'apnar',
#  'apocalypse',
#  'apocalyptic',
#  'apostates',
#  'app',
#  'appadvice',
#  'appar',
#  'apparent',
#  'appbank',
#  'appchoices',
#  'appeal',
#  'appealing',
#  'appear',
#  'appearance',
#  'appearances',
#  'appeared',
#  'appearing',
#  'appears',
#  'append',
#  'appendix',
#  'appetite',
#  'applab',
#  'apple',
#  'apples',
#  'appliaction',
#  'appliances',
#  'applicable',
#  'application',
#  'applications',
#  'applicationâ',
#  'applied',
#  'applies',
#  'applock',
#  'apply',
#  'applying',
#  'appnomics',
#  'appnomicsstudio',
#  'appoday',
#  'appointed',
#  'appointment',
#  'appreciate',
#  'appreciated',
#  'approach',
#  'approaches',
#  'appropriate',
#  'appropriately',
#  'approved',
#  'approximately',
#  'approximates',
#  'apps',
#  'appservice',
#  'appsgeyser',
#  'appstorm',
#  'aprilia',
#  'apron',
#  'aquatic',
#  'aquino',
#  'ar',
#  'ara',
#  'arab',
#  'arabia',
#  'arabian',
#  'arabic',
#  'arabs',
#  'aramaic',
#  'aramex',
#  'arbi',
#  'arc',
#  'arcade',
#  'arcades',
#  'archer',
#  'archers',
#  'archery',
#  'architectural',
#  'architecture',
#  'architectures',
#  'archive',
#  'archived',
#  'archiver',
#  'archivers',
#  'archives',
#  'archiving',
#  'archvies',
#  'arctic',
#  'arduino',
#  'are',
#  'area',
#  'areas',
#  'arena',
#  'arenas',
#  'argentina',
#  'argentine',
#  'argondeviant',
#  'argued',
#  'ariana',
#  'ariary',
#  'aris',
#  'arise',
#  'arises',
#  'arising',
#  'arizona',
#  'arm',
#  'armed',
#  'armenian',
#  'armidale',
#  'armor',
#  'armors',
#  'armoured',
#  'arms',
#  'armstrong',
#  'army',
#  'around',
#  'arrange',
#  'arranged',
#  'arrangement',
#  'arranging',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arrow',
#  'arrows',
#  'ars',
#  'arsenal',
#  'art',
#  'article',
#  'articles',
#  'artificial',
#  'artist',
#  'artistic',
#  'artists',
#  'arts',
#  'artwork',
#  'artworks',
#  'aruban',
#  'aryan',
#  'as',
#  'asap',
#  'ascend',
#  'ascending',
#  'ascii',
#  'asees',
#  'asf',
#  'ashamed',
#  'ashes',
#  'ashura',
#  'asia',
#  'ask',
#  'askar',
#  'asked',
#  'asking',
#  'asks',
#  'asleep',
#  'aspect',
#  'aspects',
#  'asperger',
#  'assam',
#  'assassin',
#  'assault',
#  'assemble',
#  'assembled',
#  'assembling',
#  'assessment',
#  'asset',
#  'assets',
#  'assign',
#  'assigned',
#  'assignment',
#  'assignments',
#  'assist',
#  'assistance',
#  'assistant',
#  'assists',
#  'associated',
#  'association',
#  'assumes',
#  'assured',
#  'assures',
#  'asthma',
#  'astound',
#  'astounds',
#  'astro',
#  'astrology',
#  'astronaut',
#  'astronomy',
#  'asus',
#  'aswell',
#  'at',
#  'ataimpactforum',
#  'athletes',
#  'atlantic',
#  'atlantis',
#  'atleast',
#  'atm',
#  'atmosphere',
#  'atmospheres',
#  'atom',
#  'atomic',
#  'atp',
#  'attach',
#  'attaching',
#  'attachments',
#  'attack',
#  'attackers',
#  'attacking',
#  'attacks',
#  'attempt',
#  'attend',
#  'attention',
#  'attest',
#  'attested',
#  'attitude',
#  'attract',
#  'attracted',
#  'attractions',
#  'attractive',
#  'attributed',
#  'attributes',
#  'attributions',
#  'atuwawa',
#  'atâ',
#  'au',
#  'aucde',
#  'auckland',
#  'aud',
#  'audience',
#  'audio',
#  'audiobooks',
#  'audios',
#  'augmentation',
#  'august',
#  'aunt',
#  'australia',
#  'australian',
#  'autanm',
#  'authentic',
#  'authentication',
#  'authenticity',
#  'author',
#  'authoritative',
#  'authorities',
#  'authority',
#  'authorize',
#  'authorized',
#  'authors',
#  'auto',
#  'autoclicks',
#  'autocollage',
#  'automagically',
#  'automate',
#  'automated',
#  'automatic',
#  'automatically',
#  'automobiles',
#  'automotive',
#  'autoplay',
#  'autosave',
#  'autoscroll',
#  'autumn',
#  'avaible',
#  'avail',
#  'available',
#  'avatar',
#  'avenue',
#  'average',
#  'avi',
#  'aviate',
#  'aviation',
#  'avid',
#  'avoid',
#  'avoiding',
#  'aw',
#  'await',
#  'awaited',
#  'awaiting',
#  'awaits',
#  'awake',
#  'awaken',
#  'award',
#  'awarded',
#  'awards',
#  'aware',
#  'awareness',
#  'awas',
#  'away',
#  'awesome',
#  'awesone',
#  'awg',
#  'awsome',
#  'axe',
#  'axes',
#  'axtel',
#  'ayah',
#  'ayat',
#  'azerbaijani',
#  'azha',
#  'azimuth',
#  'azn',
#  'aztec',
#  'azure',
#  'azwallpapersdev',
#  'ba',
#  'baad',
#  'baadshah',
#  'baadshaho',
#  'baaki',
#  'baazigar',
#  'baba',
#  'babies',
#  'baby',
#  'bachata',
#  'back',
#  'backed',
#  'background',
#  'backgrounds',
#  'backing',
#  'backlit',
#  'backs',
#  'backspa',
#  'backup',
#  'backups',
#  'backward',
#  'bad',
#  'badges',
#  'badshah',
#  'baekhyun',
#  'baffling',
#  'bafta',
#  'bag',
#  'bagchi',
#  'bags',
#  'bahag',
#  'bahamian',
#  'bahasa',
#  'bahrain',
#  'bahraini',
#  'baht',
#  'baidu',
#  'bait',
#  'baits',
#  'bake',
#  'bakery',
#  'baking',
#  'bala',
#  'balance',
#  'balanced',
#  'balboa',
#  'balcony',
#  'baldi',
#  'balearic',
#  'ball',
#  'ballerinas',
#  'ballet',
#  'balloob',
#  'balloon',
#  'balloons',
#  'ballora',
#  'balls',
#  'bam',
#  'ban',
#  'banana',
#  'bananas',
#  'band',
#  'bandit',
#  'bands',
#  'bandwidth',
#  'banging',
#  'bangla',
#  'bangladesh',
#  'bangladeshi',
#  'bank',
#  'banking',
#  'bankruptcy',
#  'banner',
#  'banners',
#  'banners_',
#  'bappa',
#  'bar',
#  'barbadian',
#  'barbell',
#  'barber',
#  'barbie',
#  'barcelona',
#  'barcode',
#  'barcodes',
#  'bare',
#  'bark',
#  'barking',
#  'barks',
#  'barn',
#  'barnyard',
#  'barracuda',
#  'barrage',
#  'barrel',
#  'barrels',
#  'barren',
#  'barrier',
#  'barriers',
#  'basal',
#  'base',
#  'baseball',
#  'based',
#  'bases',
#  'basic',
#  'basically',
#  'basics',
#  'basis',
#  'basket',
#  'basketball',
#  'baskets',
#  'basra',
#  'bass',
#  'bat',
#  'bataenge',
#  'batane',
#  'batch',
#  'bathing',
#  'bathroom',
#  'bats',
#  'batsman',
#  'battalion',
#  'battery',
#  'battle',
#  'battlefield',
#  'battlefields',
#  'battleground',
#  'battleislandsgame',
#  'battleislandshq',
#  'battles',
#  'battleship',
#  'battling',
#  'bay',
#  'bayern',
#  'bazooka',
#  'bbb',
#  'bbc',
#  'bbd',
#  'bbm',
#  'bbox',
#  'bc',
#  'bceao',
#  'bdt',
#  'beac',
#  'beach',
#  'beaches',
#  'beagle',
#  'beam',
#  'beams',
#  'beans',
#  'bear',
#  'beard',
#  'beards',
#  'bears',
#  'beast',
#  'beasts',
#  'beat',
#  'beating',
#  'beats',
#  'beauties',
#  'beautifies',
#  'beautiful',
#  'beautifully',
#  'beautify',
#  'beautifying',
#  'beauty',
#  'beauty__inc',
#  'beautyapps',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'bed',
#  'bedb',
#  'bedroom',
#  'bedside',
#  'bee',
#  'beekeeping',
#  'beer',
#  'bees',
#  'beethoven',
#  'bega',
#  'began',
#  'beggar',
#  'beggars',
#  'begin',
#  'begining',
#  'beginner',
#  'beginners',
#  'beginning',
#  'begins',
#  'begs',
#  'begun',
#  'behalf',
#  'behave',
#  'behaves',
#  'behind',
#  'beings',
#  'belarusian',
#  'belch',
#  'belgium',
#  'belief',
#  'beliefs',
#  'believable',
#  'believe',
#  'believed',
#  'believer',
#  'believes',
#  'belize',
#  'bell',
#  'bellow',
#  'bells',
#  'belly',
#  'belong',
#  'belonging',
#  'belongs',
#  'beloved',
#  'below',
#  'belt',
#  'belts',
#  ...]

# %%
cv.vocabulary_
# Out:
# {'black': 1097,
#  'box': 1272,
#  'movie': 6771,
#  'listing': 6055,
#  'app': 484,
#  'collection': 1986,
#  'list': 6050,
#  'movies': 6772,
#  'tv': 10865,
#  'shows': 9344,
#  'cater': 1630,
#  'diverse': 2959,
#  'communities': 2062,
#  'around': 591,
#  'world': 11601,
#  'simple': 9386,
#  'way': 11375,
#  'organize': 7275,
#  'make': 6271,
#  'wish': 11533,
#  'aim': 254,
#  'buy': 1459,
#  'watch': 11358,
#  'later': 5867,
#  'pulls': 8175,
#  'show': 9335,
#  'information': 5139,
#  'imdb': 5016,
#  'website': 11400,
#  'view': 11219,
#  'details': 2771,
#  'director': 2893,
#  'release': 8537,
#  'date': 2585,
#  'casts': 1614,
#  'studio': 9955,
#  'etc': 3467,
#  'offline': 7156,
#  'contains': 2220,
#  'news': 6985,
#  'media': 6458,
#  'section': 9135,
#  'informs': 5143,
#  'users': 11073,
#  'events': 3485,
#  'occurring': 7121,
#  'postings': 7876,
#  'detailed': 2770,
#  'newly': 6984,
#  'released': 8538,
#  'local': 6092,
#  'plays': 7750,
#  'popular': 7838,
#  'general': 4228,
#  'population': 7840,
#  'purchase': 8193,
#  'one': 7188,
#  'subscriptions': 9991,
#  'gain': 4158,
#  'premium': 7954,
#  'access': 62,
#  'content': 2224,
#  'subscription': 9990,
#  'also': 338,
#  'removes': 8573,
#  'advertisement': 194,
#  'specific': 9693,
#  'areas': 567,
#  'different': 2848,
#  'choose': 1806,
#  'from': 4095,
#  'monthly': 6716,
#  'ad': 128,
#  'removal': 8569,
#  'usd': 11066,
#  'annual': 436,
#  'month': 6715,
#  'duration': 3127,
#  'example': 3507,
#  'user': 11071,
#  'purchases': 8195,
#  'february': 3744,
#  'nd': 6932,
#  'account': 83,
#  'charged': 1729,
#  'every': 3488,
#  'opt': 7239,
#  'anytime': 465,
#  'going': 4348,
#  'payments': 7497,
#  'itunes': 5387,
#  'confirmation': 2161,
#  'automatically': 732,
#  'renews': 8584,
#  'unless': 10988,
#  'auto': 725,
#  'renew': 8579,
#  'turned': 10854,
#  'least': 5921,
#  'hours': 4879,
#  'end': 3329,
#  'current': 2497,
#  'period': 7551,
#  'renewal': 8581,
#  'within': 11543,
#  'prior': 8014,
#  'identify': 4972,
#  'cost': 2326,
#  'manage': 6300,
#  'turning': 10855,
#  'my': 6847,
#  'settings': 9226,
#  'features': 3742,
#  'actors': 123,
#  'actresses': 124,
#  'video': 11207,
#  'available': 741,
#  'posters': 7874,
#  'images': 5008,
#  'trailer': 10675,
#  'online': 7200,
#  'add': 137,
#  'note': 7053,
#  'share': 9257,
#  'social': 9578,
#  'platforms': 7736,
#  'stay': 9841,
#  'international': 5263,
#  'privacy': 8018,
#  'policy': 7811,
#  'http': 4898,
#  'reign': 8516,
#  'com': 2018,
#  'php': 7626,
#  'terms': 10382,
#  'use': 11067,
#  'https': 4899,
#  'conditions': 2146,
#  'fun': 4120,
#  'game': 4173,
#  'challenging': 1701,
#  'episodes': 3419,
#  'apples': 503,
#  'added': 138,
#  'bonus': 1220,
#  'score': 9069,
#  'points': 7798,
#  'knives': 5702,
#  'throw': 10492,
#  'scores': 9073,
#  'get': 4263,
#  'new': 6980,
#  'blades': 1106,
#  'types': 10884,
#  'swords': 10168,
#  'made': 6228,
#  'impressive': 5048,
#  'progressive': 8081,
#  'graphics': 4415,
#  'layout': 5895,
#  'grid': 4437,
#  'collage': 1975,
#  'square': 9768,
#  'crop': 2434,
#  'instagram': 5198,
#  'blur': 1169,
#  'color': 1998,
#  'splash': 9731,
#  'mirror': 6617,
#  'filter': 3815,
#  'light': 6007,
#  'leak': 5911,
#  'lens': 5950,
#  'flare': 3890,
#  'texture': 10415,
#  'photo': 7612,
#  'facebook': 3637,
#  'whatsapp': 11435,
#  'snapchat': 9558,
#  'magical': 6240,
#  'editor': 3198,
#  'create': 2392,
#  'beautiful': 940,
#  'amazing': 350,
#  'lidow': 5994,
#  'let': 5960,
#  'become': 949,
#  'unique': 10972,
#  'said': 8946,
#  'fav': 3723,
#  'edit': 3193,
#  'bestest': 1017,
#  'best': 1016,
#  'thumbs': 10498,
#  'people': 7531,
#  'try': 10818,
#  'really': 8401,
#  'makes': 6277,
#  'editing': 3196,
#  'skills': 9457,
#  'look': 6133,
#  'professional': 8059,
#  'suggest': 10017,
#  'everyone': 3491,
#  'million': 6586,
#  'stars': 9814,
#  'rate': 8350,
#  'love': 6163,
#  'ever': 3486,
#  'deserves': 2748,
#  'five': 3878,
#  'seen': 9151,
#  'thank': 10422,
#  'developers': 2790,
#  'creating': 2395,
#  'lovely': 6165,
#  'absolutely': 39,
#  'great': 4423,
#  'time': 10533,
#  'favorite': 3726,
#  'very': 11179,
#  'useful': 11069,
#  'gud': 4481,
#  'awesome': 765,
#  'options': 7253,
#  'photos': 7623,
#  'grateful': 4419,
#  'never': 6979,
#  'see': 9142,
#  'no': 7030,
#  'give': 4300,
#  'effect': 3209,
#  'easy': 3171,
#  'magic': 6239,
#  'the': 10429,
#  'special': 9686,
#  'powerful': 7898,
#  'adjustment': 165,
#  'function': 4121,
#  'overlay': 7331,
#  'gradient': 4393,
#  'adjust': 161,
#  'brightness': 1337,
#  'contrast': 2243,
#  'saturation': 9000,
#  'sharpness': 9269,
#  'save': 9004,
#  'phone': 7607,
#  'to': 10571,
#  'twitter': 10876,
#  'line': 6034,
#  'email': 3266,
#  'superstar': 10069,
#  'photographer': 7617,
#  'notice': 7060,
#  'pro': 8031,
#  'offers': 7149,
#  'two': 10877,
#  'renewing': 8583,
#  'days': 2592,
#  'free': 4061,
#  'trial': 10755,
#  'billed': 1060,
#  'expires': 3578,
#  'payment': 7496,
#  '_hours': 4,
#  'may': 6421,
#  'managed': 6301,
#  'unused': 11017,
#  'portion': 7848,
#  'offered': 7146,
#  'forfeited': 3997,
#  'publication': 8159,
#  'applicable': 506,
#  'privacypolicy': 8021,
#  'picsjoin': 7648,
#  'ios': 5324,
#  'lidowpro': 5995,
#  'html': 4897,
#  'termsofuse': 10384,
#  'questions': 8252,
#  'contact': 2213,
#  'us': 11059,
#  'follow': 3958,
#  'caesar_app': 1487,
#  'like': 6018,
#  'thecaesarapp': 10433,
#  'caesarapp': 1488,
#  'weibo': 11413,
#  'wechat': 11404,
#  'vidstitch': 11215,
#  'featured': 3741,
#  'apps': 529,
#  'stelapps': 9858,
#  'many': 6341,
#  'seamlessly': 9116,
#  'combines': 2025,
#  'videos': 11211,
#  'vidstich': 11214,
#  'designed': 2751,
#  'exclusively': 3529,
#  'ground': 4451,
#  'engineered': 3357,
#  'intuitive': 5292,
#  'effortless': 3218,
#  'experience': 3563,
#  'intelligent': 5232,
#  'automagically': 728,
#  'optimizes': 7245,
#  'handle': 4575,
#  'everything': 3492,
#  'background': 793,
#  'less': 5957,
#  'interface': 5254,
#  'frame': 4048,
#  'combine': 2023,
#  'multiple': 6809,
#  'frames': 4049,
#  'ipad': 5326,
#  'compatibility': 2075,
#  'ui': 10905,
#  'optimized': 7244,
#  'border': 1239,
#  'patterns': 7489,
#  'rounded': 8865,
#  'corners': 2306,
#  'upgrade': 11033,
#  'allows': 322,
#  'clips': 1902,
#  'soundtrack': 9650,
#  'compatible': 2076,
#  'iphone': 5329,
#  'used': 11068,
#  'cause': 1637,
#  'crashes': 2381,
#  'instability': 5195,
#  'issues': 5370,
#  'please': 7756,
#  'using': 11075,
#  'ton': 10591,
#  'overwork': 7342,
#  'overload': 7334,
#  'processing': 8043,
#  'power': 7896,
#  'modest': 6669,
#  'fresh': 4076,
#  'squeezed': 9775,
#  'dedicated': 2645,
#  'bringing': 1341,
#  'clean': 1872,
#  'quality': 8241,
#  'convenient': 2254,
#  'comments': 2048,
#  'suggestions': 10020,
#  'contactus': 2215,
#  'freshsqueezedapps': 4078,
#  'connect': 2172,
#  'hashtag': 4626,
#  'trademark': 10664,
#  'llc': 6081,
#  'rights': 8770,
#  'reserved': 8639,
#  'cat': 1616,
#  'hiding': 4735,
#  'come': 2030,
#  'find': 3826,
#  'inside': 5180,
#  'room': 8844,
#  'progress': 8078,
#  'stage': 9796,
#  'hide': 4732,
#  'unlikely': 10990,
#  'place': 7708,
#  'sometimes': 9619,
#  'items': 5381,
#  'hidden': 4731,
#  'application': 507,
#  'escape': 3447,
#  'style': 9966,
#  'play': 7739,
#  'tap': 10272,
#  'item': 5380,
#  'drag': 3054,
#  'drop': 3096,
#  'martial': 6371,
#  'arts': 611,
#  'codified': 1963,
#  'systems': 10202,
#  'traditions': 10670,
#  'combat': 2020,
#  'practiced': 7909,
#  'number': 7086,
#  'reasons': 8409,
#  'self': 9165,
#  'defense': 2663,
#  'military': 6582,
#  'law': 5887,
#  'enforcement': 3352,
#  'applications': 508,
#  'competition': 2082,
#  'physical': 7630,
#  'mental': 6503,
#  'spiritual': 9729,
#  'development': 2792,
#  'well': 11421,
#  'entertainment': 3397,
#  'preservation': 7969,
#  'nation': 6904,
#  'intangible': 5222,
#  'cultural': 2480,
#  'heritage': 4718,
#  'although': 342,
#  'term': 10379,
#  'art': 604,
#  'associated': 653,
#  'fighting': 3798,
#  'east': 3168,
#  'asia': 626,
#  'originally': 7285,
#  'referred': 8481,
#  'europe': 3475,
#  'early': 3146,
#  'derived': 2731,
#  'latin': 5871,
#  'means': 6444,
#  'mars': 6368,
#  'roman': 8832,
#  'god': 4341,
#  'war': 11332,
#  'authors': 724,
#  'argued': 573,
#  'appropriate': 524,
#  'basis': 886,
#  'sense': 9182,
#  'created': 2393,
#  'warriors': 11344,
#  'wallpaper': 11323,
#  'fans': 3691,
#  'wallpapers': 11324,
#  'enjoy': 3372,
#  'hundreds': 4918,
#  'android': 402,
#  'thing': 10453,
#  'interested': 5250,
#  'continue': 2235,
#  'updated': 11026,
#  'feature': 3740,
#  'hd': 4650,
#  'jiu': 5465,
#  'jitsu': 5464,
#  'judo': 5520,
#  'karate': 5559,
#  'aikido': 251,
#  'taekwondo': 10224,
#  'kick': 5620,
#  'boxing': 1275,
#  'kungfu': 5770,
#  'fight': 3795,
#  'muay': 6791,
#  'thai': 10420,
#  'silat': 9378,
#  'bruce': 1371,
#  'lee': 5930,
#  'need': 6948,
#  'internet': 5264,
#  'conection': 2148,
#  'welcome': 11417,
#  'feedback': 3749,
#  'happy': 4604,
#  'surfing': 10095,
#  'disclaimer': 2907,
#  'unofficial': 11000,
#  'affiliated': 216,
#  'endorsed': 3340,
#  'sponsored': 9738,
#  'specifically': 9694,
#  'approved': 526,
#  'company': 2070,
#  'mainly': 6261,
#  'trend': 10748,
#  'fashion': 3708,
#  'google': 4364,
#  'image': 5007,
#  'search': 9117,
#  'support': 10078,
#  'reverse': 8720,
#  'mobile': 6655,
#  'browser': 1368,
#  'rd': 8370,
#  'party': 7453,
#  'tool': 10599,
#  'detect': 2772,
#  'truth': 10815,
#  'want': 11329,
#  'visually': 11262,
#  'similar': 9384,
#  'able': 24,
#  'services': 9216,
#  'device': 2796,
#  'pick': 7640,
#  'gallery': 4168,
#  'take': 10242,
#  'camera': 1522,
#  'rotate': 8856,
#  'flip': 3912,
#  'upload': 11041,
#  'results': 8694,
#  'review': 8724,
#  'know': 5704,
#  'read': 8382,
#  'related': 8525,
#  'face': 3636,
#  'reveals': 8714,
#  'lot': 6154,
#  'future': 4151,
#  'career': 1575,
#  'wealth': 11384,
#  'health': 4673,
#  'facial': 3641,
#  'might': 6573,
#  'meet': 6469,
#  'partner': 7448,
#  'machine': 6220,
#  'you': 11720,
#  're': 8371,
#  'even': 3482,
#  'years': 11700,
#  'old': 7171,
#  'consultant': 2207,
#  'beauty': 944,
#  'index': 5099,
#  'today': 10575,
#  'report': 8610,
#  'taking': 10245,
#  'includes': 5078,
#  'fortune': 4023,
#  'work': 11588,
#  'gender': 4227,
#  'swap': 10137,
#  'imagined': 5012,
#  'male': 6292,
#  'version': 11175,
#  'female': 3761,
#  'exotic': 3548,
#  'blend': 1118,
#  'origins': 7286,
#  'native': 6906,
#  'american': 361,
#  'ancient': 394,
#  'egyptian': 3227,
#  'indian': 5101,
#  'ethnicity': 3471,
#  'scanner': 9034,
#  'reveal': 8712,
#  'bloodlines': 1150,
#  'body': 1197,
#  'check': 1754,
#  'predictor': 7943,
#  'mr': 6784,
#  'right': 8768,
#  'telling': 10356,
#  'marriage': 6366,
#  'baby': 789,
#  'happiness': 4603,
#  'looks': 6136,
#  'lover': 6166,
#  'contest': 2226,
#  'friends': 4085,
#  'result': 8692,
#  'pay': 7493,
#  'attention': 688,
#  'relationship': 8528,
#  'zodiac': 11763,
#  'signs': 9375,
#  'horoscope': 4850,
#  'prediction': 7941,
#  'daily': 2550,
#  'weekly': 11411,
#  'yearly': 11699,
#  'tell': 10355,
#  'crystal': 2465,
#  'ball': 830,
#  'ask': 627,
#  'ideal': 4964,
#  'hard': 4607,
#  'decisions': 2627,
#  'guidance': 4491,
#  'maybe': 6423,
#  'something': 9618,
#  'surprised': 10103,
#  'lucky': 6187,
#  'numbers': 7089,
#  'wear': 11389,
#  'luck': 6184,
#  'reading': 8389,
#  'characteristic': 1724,
#  'family': 3683,
#  'articles': 606,
#  'aspects': 634,
#  'life': 5997,
#  'supplied': 10075,
#  'acknowledged': 103,
#  'secret': 9132,
#  'neon': 6964,
#  'pastel': 7474,
#  'heart': 4679,
#  'theme': 10436,
#  'keyboard': 5599,
#  'install': 5199,
#  'if': 4985,
#  'looking': 6135,
#  'themes': 10439,
#  'personalize': 7569,
#  'perfect': 7538,
#  'smart': 9516,
#  'typing': 10887,
#  'start': 9816,
#  'enjoying': 3375,
#  'splendid': 9732,
#  'apply': 513,
#  'download': 3042,
#  'store': 9891,
#  'open': 7211,
#  'it': 5373,
#  'click': 1886,
#  'button': 1456,
#  'preview': 7987,
#  'picture': 7649,
#  'bravo': 1301,
#  'installed': 5202,
#  'applied': 510,
#  'press': 7972,
#  'finish': 3840,
#  'provides': 8135,
#  'amount': 372,
#  'stylish': 9971,
#  'decorate': 2636,
#  'cool': 2278,
#  'cute': 2520,
#  'romantic': 8837,
#  'cartoon': 1600,
#  'panda': 7401,
#  'unicorn': 10965,
#  'anime': 423,
#  'lion': 6043,
#  'clown': 1927,
#  'sport': 9746,
#  'girl': 4292,
#  'skull': 9462,
#  'soccer': 9576,
#  'wolf': 11564,
#  'graffiti': 4398,
#  'car': 1568,
#  'flower': 3931,
#  'music': 6826,
#  'colorful': 2000,
#  'gold': 4350,
#  'green': 4430,
#  'pink': 7676,
#  'red': 8461,
#  'purple': 8202,
#  'blue': 1162,
#  'white': 11462,
#  'topics': 10606,
#  'usually': 11080,
#  'update': 11025,
#  'times': 10541,
#  'week': 11409,
#  'keep': 5587,
#  'frequently': 4075,
#  'key': 5598,
#  'languages': 5848,
#  'supported': 10079,
#  'text': 10411,
#  'ʕʘ': 11778,
#  'ʘʔ': 11779,
#  'clipboard': 1900,
#  'fast': 3711,
#  'copy': 2294,
#  'paste': 7473,
#  'diy': 2967,
#  'customizable': 2512,
#  'input': 5171,
#  'thousands': 10477,
#  'emojis': 3291,
#  'dictionaries': 2836,
#  'gifs': 4282,
#  'emoticons': 3294,
#  'stickers': 9867,
#  'anywhere': 467,
#  'conveniently': 2255,
#  'contextual': 2229,
#  'error': 3443,
#  'correction': 2315,
#  'correct': 2312,
#  'mistyping': 6629,
#  'spelling': 9712,
#  'errors': 3444,
#  'capitalization': 1556,
#  'cloud': 1923,
#  'enhance': 3365,
#  'next': 6994,
#  'word': 11582,
#  'predictions': 7942,
#  'computing': 2128,
#  'multi': 6799,
#  'language': 5847,
#  'loved': 6164,
#  'deeply': 2652,
#  'still': 9872,
#  'counting': 2341,
#  'including': 5079,
#  'limited': 6032,
#  'english': 3363,
#  'العربية': 11797,
#  'hrvatski': 4891,
#  'čeština': 11776,
#  'nederlands': 6946,
#  'français': 4057,
#  'deutsch': 2784,
#  'ελληνικά': 11780,
#  'בר': 11788,
#  'ית': 11789,
#  'bahasa': 813,
#  'indonesia': 5119,
#  'italiano': 5376,
#  'malay': 6288,
#  'pilipino': 7666,
#  'polskie': 7820,
#  'português': 7857,
#  'română': 8840,
#  'русский': 11786,
#  'español': 3450,
#  'ไทย': 11997,
#  'türk': 10892,
#  'euskara': 3477,
#  'ಕನ': 11993,
#  'ನಡ': 11994,
#  'ພາສາລາວ': 11998,
#  'മലയ': 11995,
#  'монгол': 11783,
#  'தம': 11992,
#  'zulu': 11772,
#  'devices': 2797,
#  'almost': 327,
#  'phones': 7609,
#  'samsung': 8971,
#  'galaxy': 4164,
#  'edge': 3190,
#  'sony': 9628,
#  'xperia': 11680,
#  'huawei': 4900,
#  'plus': 7779,
#  'mate': 6403,
#  'honor': 4827,
#  'htc': 4894,
#  'oppo': 7231,
#  'xiaomi': 11670,
#  'mix': 6634,
#  'nokia': 7035,
#  'vivo': 11267,
#  'moto': 6748,
#  'worry': 11606,
#  'security': 9141,
#  'we': 11381,
#  'collect': 1982,
#  'personal': 7564,
#  'info': 5135,
#  'set': 9221,
#  'words': 11585,
#  'typed': 10883,
#  'accurate': 89,
#  'charm': 1737,
#  'feeling': 3753,
#  'attractive': 695,
#  'arabic': 542,
#  'voice': 11278,
#  'backgrounds': 794,
#  'recording': 8451,
#  'write': 11628,
#  'messages': 6527,
#  'via': 11189,
#  'keypad': 5602,
#  'keys': 5604,
#  'keypads': 5603,
#  'demanding': 2696,
#  'custom': 2507,
#  'ultra': 10912,
#  'efficient': 3215,
#  'mobiles': 6657,
#  'fastest': 3714,
#  'recognition': 8437,
#  'technology': 10340,
#  'recognize': 8438,
#  'convert': 2260,
#  'speech': 9701,
#  'products': 8056,
#  'accents': 58,
#  'contain': 2216,
#  'إسرائيل': 11790,
#  'israel': 5367,
#  'الأردن': 11791,
#  'jordan': 5493,
#  'الإمارات': 11792,
#  'united': 10976,
#  'arab': 539,
#  'emirates': 3287,
#  'البحرين': 11793,
#  'bahrain': 814,
#  'الجزائر': 11794,
#  'algeria': 296,
#  'السعودية': 11795,
#  'saudi': 9001,
#  'arabia': 540,
#  'العراق': 11796,
#  'iraq': 5337,
#  'الكويت': 11798,
#  'kuwait': 5773,
#  'المغرب': 11799,
#  'morocco': 6730,
#  'تونس': 11800,
#  'tunisia': 10843,
#  'مان': 11805,
#  'oman': 7177,
#  'فلسطين': 11802,
#  'state': 9827,
#  'palestine': 7395,
#  'قطر': 11803,
#  'qatar': 8231,
#  'لبنان': 11804,
#  'lebanon': 5927,
#  'مصر': 11806,
#  'egypt': 3226,
#  'enriched': 3383,
#  'arbi': 546,
#  'qeda': 8233,
#  'qaeeda': 8229,
#  'option': 7251,
#  'record': 8447,
#  'called': 1507,
#  'alphabetic': 334,
#  'help': 4706,
#  'speaking': 9682,
#  'send': 9176,
#  'receive': 8423,
#  'upgraded': 11034,
#  'rich': 8753,
#  'vocabulary': 11272,
#  'board': 1182,
#  'keyboards': 5600,
#  'thousand': 10476,
#  'ease': 3163,
#  'delete': 2677,
#  'cleave': 1883,
#  'far': 3697,
#  'translation': 10707,
#  'working': 11593,
#  'soon': 9630,
#  'include': 5076,
#  'sending': 9178,
#  'emoji': 3289,
#  'chats': 1747,
#  'fonts': 3967,
#  'more': 6724,
#  'styles': 9969,
#  'size': 9440,
#  'change': 1709,
#  'taping': 10274,
#  'sounds': 9648,
#  'vibration': 11197,
#  'networks': 6976,
#  'searching': 9121,
#  'enable': 3310,
#  'disable': 2899,
#  'alphabets': 336,
#  'adjusting': 164,
#  'alphabet': 333,
#  'traditional': 10668,
#  'tapping': 10279,
#  'musical': 6827,
#  'first': 3863,
#  'menu': 6506,
#  'setting': 9225,
#  'second': 9129,
#  'select': 9159,
#  'pop': 7833,
#  'appears': 497,
#  'default': 2658,
#  'choice': 1804,
#  'adding': 146,
#  'closing': 1918,
#  'star': 9809,
#  'fore': 3984,
#  'visit': 11256,
#  'home': 4813,
#  'page': 7372,
#  'single': 9413,
#  'day': 2590,
#  'documents': 2990,
#  'scanned': 9033,
#  'situation': 9433,
#  'planned': 7726,
#  'definitely': 2667,
#  'suffer': 10012,
#  'scan': 9032,
#  'document': 2987,
#  'arises': 578,
#  'disaster': 2903,
#  'sure': 10088,
#  'rescue': 8632,
#  'cv': 2526,
#  'infotech': 5145,
#  'brings': 1342,
#  'portable': 7842,
#  'doc': 2984,
#  'additional': 148,
#  'scanning': 9036,
#  'good': 4361,
#  'tour': 10630,
#  'manually': 6335,
#  'enhancement': 3367,
#  'cropping': 2436,
#  'optimize': 7243,
#  'pdf': 7503,
#  'modes': 6668,
#  'lighten': 6008,
#  'dark': 2571,
#  'turn': 10853,
#  'scans': 9037,
#  'clear': 1878,
#  'sharp': 9265,
#  'arrange': 592,
#  'folder': 3953,
#  'sub': 9975,
#  'folders': 3954,
#  'jpeg': 5510,
#  'files': 3807,
#  'print': 8009,
#  'fax': 3730,
#  'directly': 2892,
#  'drive': 3089,
#  'dropbox': 3097,
#  'qr': 8236,
#  'code': 1954,
#  'bar': 857,
#  'turns': 10856,
#  'removing': 8574,
#  'noise': 7032,
#  'sizes': 9442,
#  'postcard': 7871,
#  'letter': 5963,
#  'translate': 10703,
#  'appreciated': 521,
#  'url': 11055,
#  'cvinfotech': 2528,
#  'oneskyapp': 7196,
#  'collaboration': 1973,
#  'project': 8083,
#  'id': 4962,
#  'glance': 4309,
#  'efforts': 3220,
#  'quickly': 8260,
#  'anything': 464,
#  'fly': 3941,
#  'paper': 7412,
#  'third': 10457,
#  'storage': 9890,
#  'papers': 7413,
#  'lite': 6060,
#  'saved': 9005,
#  'format': 4007,
#  'detection': 2775,
#  'additionally': 149,
#  'type': 10882,
#  'grey': 4435,
#  'sky': 9464,
#  'instant': 5208,
#  'smartphone': 9519,
#  'scanners': 9035,
#  'creator': 2400,
#  'file': 3806,
#  'another': 440,
#  'integrated': 5225,
#  'ocr': 7127,
#  'upcoming': 11024,
#  'texts': 10414,
#  'high': 4737,
#  'match': 6398,
#  'digitally': 2864,
#  'original': 7284,
#  'converter': 2262,
#  'cam': 1517,
#  'whiteboard': 11463,
#  'blackboard': 1099,
#  'produce': 8046,
#  'exactly': 3503,
#  'required': 8627,
#  'remove': 8570,
#  'grain': 4399,
#  'various': 11129,
#  ...}

# %%
# Step 5. TfidfTransformer to compute the IDF
from sklearn.feature_extraction.text import TfidfTransformer
tfidfTransformer = TfidfTransformer(smooth_idf=True, use_idf=True)
tfidfTransformer.fit(dtm)
# Out:
# TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)

# %%
# get the document that we want to extract from
doc_test = row1 = df_pd_desc_final['description_join'][0]

# generate tfidf vector for given doc
tf_idf_vector = tfidfTransformer.transform(cv.transform([doc_test]))

# %%
# Return a COOrdinate representation of this matrix
coo_matrix = tf_idf_vector.tocoo()
sorted_items = sort_coo(coo_matrix)

# extract keywords, topn
keywords = extract_topn_from_vector(feature_names,sorted_items,10)

# print result
for k in keywords:
    print(k,keywords[k])
# Out:
# _________ 0.315
# __________ 0.261
# ___________________________________________ 0.238
# ________features____ 0.201
# _hours 0.198
# _w 0.186
# aac 0.167
# aagaz 0.165
# aaja 0.165
# aana 0.159

# %%
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col,coo_matrix.data)
    return sorted(tuples,key=lambda x:(x[1],x[0]),reverse=True)

def extract_topn_from_vector(feature_names,sorted_items,topn):
    """get the feature names according to the tf-idf score of top-n items"""
    
    #use only top-n itmes
    sorted_items = sorted_items[:topn]
    
    score_vals = []
    features_vals = []
    
    # word index and corresponding tf-idf score
    for index,score in sorted_items:
        
        #feature name and score
        score_vals.append(round(score,3))
        features_vals.append(feature_names[index])
        
    # create a tuples of feature,score
    results = {}
    for index in range(len(features_vals)):
        results[feature_names[index]] = score_vals[index]
        
    return results
