# %%
import pyspark
from pyspark.sql.functions import col,when,size,min, max,length
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.master('local[*]').appName('topic_modelling').getOrCreate()

# %%
df_parquet = spark.read.parquet("part-00000-a8a717e8-bf83-42e3-a0b7-084971053d99-c000.snappy.parquet")

# %%
# general understanding of the dataset
df_parquet.printSchema()
print(df_parquet.count())
df_parquet.describe().show()
# Out:
# root
#  |-- app_name: string (nullable = true)
#  |-- bundle: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- genres: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- os_platform: string (nullable = true)
#
# 865
# +-------+--------------------+--------------------+--------------------+-----------+
# |summary|            app_name|              bundle|         description|os_platform|
# +-------+--------------------+--------------------+--------------------+-----------+
# |  count|                 865|                 865|                 865|        865|
# |   mean|              2048.0|1.0872837703941176E9|                null|       null|
# | stddev|                 NaN|  3.16782382724795E8|                null|       null|
# |    min|1000 Pantun Rayua...|          1003730047|"Best Game for Ca...|    ANDROID|
# |    max|🦁🐼Jungle Animal...| xyz.goro3goro.igo19|🥉
# Aplikasi ini m...|        IOS|
# +-------+--------------------+--------------------+--------------------+-----------+

# %%
df_parquet.select(col('app_name')).show(10,False)
# Out:
# +--------------------------------------------------+
# |app_name                                          |
# +--------------------------------------------------+
# |Black Box - Movie Listing                         |
# |Knife Throwing Max                                |
# |爆料公社                                          |
# |Lidow - Photo Editor & Collage                    |
# |Vidstitch Frames for Instagram                    |
# |Where's my Cat? -Escape Game-                     |
# |Martial Art Wallpaper                             |
# |더 스파이크                                       |
# |Image detector                                    |
# |Horoscope - Face Secret - See Future - Make me old|
# +--------------------------------------------------+
# only showing top 10 rows

# %%
# size of the genre list is between 1 and 3
df_size_genres = df_parquet.select(size(col('genres')).alias("size"))
#df_size_genres.show()
df_size_genres.agg(min('size'),max('size')).show()
# Out:
# +---------+---------+
# |min(size)|max(size)|
# +---------+---------+
# |        1|        3|
# +---------+---------+

# %%
# length of 'description' column 
df_description_length = df_parquet.select(length(col('description')).alias('length'))
df_description_length.agg(min('length'),max('length')).show()
# Out:
# +-----------+-----------+
# |min(length)|max(length)|
# +-----------+-----------+
# |          9|       4000|
# +-----------+-----------+

# %%
# os_platform
df_parquet.select(col('os_platform')).distinct().show()
# Out:
# +-----------+
# |os_platform|
# +-----------+
# |    ANDROID|
# |        IOS|
# +-----------+

# %%
# no null value in 'description' and 'genres' column
df_parquet.filter(col("description").isNull()).show()
df_parquet.filter(col("genres").isNull()).show()
df_parquet.filter(col("app_name").isNull()).show()
df_parquet.filter(col("bundle").isNull()).show()
df_parquet.filter(col("os_platform").isNull()).show()
# Out:
# +--------+------+-----------+------+-----------+
# |app_name|bundle|description|genres|os_platform|
# +--------+------+-----------+------+-----------+
# +--------+------+-----------+------+-----------+
#
# +--------+------+-----------+------+-----------+
# |app_name|bundle|description|genres|os_platform|
# +--------+------+-----------+------+-----------+
# +--------+------+-----------+------+-----------+
#
# +--------+------+-----------+------+-----------+
# |app_name|bundle|description|genres|os_platform|
# +--------+------+-----------+------+-----------+
# +--------+------+-----------+------+-----------+
#
# +--------+------+-----------+------+-----------+
# |app_name|bundle|description|genres|os_platform|
# +--------+------+-----------+------+-----------+
# +--------+------+-----------+------+-----------+
#
# +--------+------+-----------+------+-----------+
# |app_name|bundle|description|genres|os_platform|
# +--------+------+-----------+------+-----------+
# +--------+------+-----------+------+-----------+

# %%
# create a column and put in the detected language code
from langdetect import detect
# app_name_result = df_parquet.select(col('description')).collect()
# # create udf function to add a new column
# import pyspark.sql.functions as F
# from pyspark.sql.types import *

# def detect_lang(value):
#   return detect(value)

# #convert to a UDF Function by passing in the function and return type of function
# udf_detect_lang = F.udf(detect_lang, StringType())
# df_with_code = df_parquet.withColumn('lang_code', udf_detect_lang(df_parquet.description))
# df_with_code.show(5)

# easier method to convert to pandas then apply then function
df_parquet_pd = df_parquet.toPandas()
df_parquet_pd['lang_code'] = df_parquet_pd['description'].apply(getCode)
df_parquet_pd
# Out:
#                                app_name  \
# 0             Black Box - Movie Listing
# 1                    Knife Throwing Max
# 2                                  爆料公社
# 3        Lidow - Photo Editor & Collage
# 4        Vidstitch Frames for Instagram
# ..                                  ...
# 860  Barber Hair Salon & Beard Makeover
# 861               DJ Remix Offline 2020
# 862             Sahih Bukhari (English)
# 863                  Two Minute English
# 864              Galaxy S9 purple Theme
#
#                                             bundle  \
# 0                                        958957112
# 1                                       1491396285
# 2                                       1387765782
# 3                                        894532288
# 4                                        712908978
# ..                                             ...
# 860  com.hmg.haircutgames.beardsalon.barberhaircut
# 861                    com.mpro.djremixoffline2020
# 862                   com.bangladroid.sahihbukhari
# 863                  com.astrobix.twominuteenglish
# 864                  com.thegosa.s9purplefreetheme
#
#                                            description  \
# 0    Black Box Movie Listing App is a collection li...
# 1    you will have fun in this game\n100+ challengi...
# 2    全台最大社群「爆料公社」APP 上線啦，我們把社群解放了，不只有勁爆的爆料內容，還貼心的加上...
# 3    layout/grid/collage、Square/no crop for instagr...
# 4    ■ #Vidstitch\n■ Featured on 148apps, Stelapps,...
# ..                                                 ...
# 860  Barber hair makeover salon game is for those w...
# 861  Dj Remix Offline 2020 Mp3 merupakan aplikasi m...
# 862  We have made this application from the book of...
# 863  Improve your spoken English rapidly with the h...
# 864  Now this application is a full theme for all s...
#
#                                       genres os_platform lang_code
# 0    [Entertainment, Magazines & Newspapers]         IOS        en
# 1         [Games_Sports, Games_Role Playing]         IOS        en
# 2                        [Social Networking]         IOS     zh-tw
# 3                            [Photo & Video]         IOS        en
# 4         [Photo & Video, Social Networking]         IOS        en
# ..                                       ...         ...       ...
# 860          [ENTERTAINMENT, FAMILY_PRETEND]     ANDROID        en
# 861                        [MUSIC_AND_AUDIO]     ANDROID        id
# 862                    [BOOKS_AND_REFERENCE]     ANDROID        en
# 863                              [EDUCATION]     ANDROID        en
# 864                        [PERSONALIZATION]     ANDROID        en
#
# [865 rows x 6 columns]

# %%
getCode = lambda x:detect(x)
sent = "this is eng"
getCode(sent)
# Out:
# 'en'

# %%
# different language code
df_parquet_pd.groupby(['lang_code']).count()
# Out:
#            app_name  bundle  description  genres  os_platform
# lang_code
# ar               10      10           10      10           10
# bn               15      15           15      15           15
# cs                1       1            1       1            1
# de                1       1            1       1            1
# en              686     686          686     686          686
# es                2       2            2       2            2
# fr                4       4            4       4            4
# hr                2       2            2       2            2
# id               82      82           82      82           82
# it                2       2            2       2            2
# ja                4       4            4       4            4
# ko                9       9            9       9            9
# pt                2       2            2       2            2
# ru                2       2            2       2            2
# sl                1       1            1       1            1
# so                1       1            1       1            1
# th                9       9            9       9            9
# tl                1       1            1       1            1
# tr                3       3            3       3            3
# vi               16      16           16      16           16
# zh-cn             9       9            9       9            9
# zh-tw             3       3            3       3            3

# %%
# observe "language code" column, check whether NULL value exists
df_parquet_pd[df_parquet_pd.lang_code.isnull()]
# Out:
# Empty DataFrame
# Columns: [app_name, bundle, description, genres, os_platform, lang_code]
# Index: []

# %%
# inspect 'description' in english
df_parquet_pd.loc[df_parquet_pd['lang_code']=='en']
# Out:
#                                app_name  \
# 0             Black Box - Movie Listing
# 1                    Knife Throwing Max
# 3        Lidow - Photo Editor & Collage
# 4        Vidstitch Frames for Instagram
# 5         Where's my Cat? -Escape Game-
# ..                                  ...
# 859                   Mining Dictionary
# 860  Barber Hair Salon & Beard Makeover
# 862             Sahih Bukhari (English)
# 863                  Two Minute English
# 864              Galaxy S9 purple Theme
#
#                                             bundle  \
# 0                                        958957112
# 1                                       1491396285
# 3                                        894532288
# 4                                        712908978
# 5                                       1259238703
# ..                                             ...
# 859                  best2018apps.miningdictionary
# 860  com.hmg.haircutgames.beardsalon.barberhaircut
# 862                   com.bangladroid.sahihbukhari
# 863                  com.astrobix.twominuteenglish
# 864                  com.thegosa.s9purplefreetheme
#
#                                            description  \
# 0    Black Box Movie Listing App is a collection li...
# 1    you will have fun in this game\n100+ challengi...
# 3    layout/grid/collage、Square/no crop for instagr...
# 4    ■ #Vidstitch\n■ Featured on 148apps, Stelapps,...
# 5    The cat is hiding and won't come out!\nFind th...
# ..                                                 ...
# 859  Thousands of Mining Words and Terms\nIf you ha...
# 860  Barber hair makeover salon game is for those w...
# 862  We have made this application from the book of...
# 863  Improve your spoken English rapidly with the h...
# 864  Now this application is a full theme for all s...
#
#                                               genres os_platform lang_code
# 0            [Entertainment, Magazines & Newspapers]         IOS        en
# 1                 [Games_Sports, Games_Role Playing]         IOS        en
# 3                                    [Photo & Video]         IOS        en
# 4                 [Photo & Video, Social Networking]         IOS        en
# 5    [Entertainment, Games_Family, Games_Simulation]         IOS        en
# ..                                               ...         ...       ...
# 859                            [BOOKS_AND_REFERENCE]     ANDROID        en
# 860                  [ENTERTAINMENT, FAMILY_PRETEND]     ANDROID        en
# 862                            [BOOKS_AND_REFERENCE]     ANDROID        en
# 863                                      [EDUCATION]     ANDROID        en
# 864                                [PERSONALIZATION]     ANDROID        en
#
# [686 rows x 6 columns]

# %%
# inspect 'description' in english
df_parquet_pd.loc[df_parquet_pd['lang_code']!='en']
# Out:
#                             app_name                                bundle  \
# 2                               爆料公社                            1387765782
# 7                             더 스파이크            com.daerisoft.thespikelive
# 12    Cara Menggunakan Jam Imoo Anak                     com.jamimoo.guide
# 13                   สวัสดี วันเสาร์                    com.thdev.saturday
# 20   Lagu Dangdut Hamdan ATT Offline                      com.zakiy.hamdan
# ..                               ...                                   ...
# 842         O'zbek  - Rusda Tarjimon    com.linguaapps.translator.uzbek.ru
# 854                   Muu Ke Tan Gai           com.vnmacstudio.muuketangai
# 855            الأم في الفقه الشافعي            so.ateya.ahmed.elom_shafay
# 858          Lagu Galau Offline 2020  com.kermaxdevteam.lagugalaupatahhati
# 861            DJ Remix Offline 2020           com.mpro.djremixoffline2020
#
#                                            description                 genres  \
# 2    全台最大社群「爆料公社」APP 上線啦，我們把社群解放了，不只有勁爆的爆料內容，還貼心的加上...    [Social Networking]
# 7    게임의 난이도가 조금 어려울수도 있습니다.\n연습을 조금 하시면 더 쉽게 적응하실 ...          [GAME_SPORTS]
# 12   Imoo Watch Phone hadir dengan berbagai fitur m...  [BOOKS_AND_REFERENCE]
# 13   แอพที่กำลังฮิตตอนนี้ เป็นแอพที่รวบรวมคำสวัสดี ...               [SOCIAL]
# 20   Aplikasi Ini Bersifat Offline Sehingga Tidak M...      [MUSIC_AND_AUDIO]
# ..                                                 ...                    ...
# 842  O'zbek  - Rusda Tarjimon dasturi - bepul va ul...  [BOOKS_AND_REFERENCE]
# 854  Bạn là một chàng trai tài năng, điển trai nhưn...  [BOOKS_AND_REFERENCE]
# 855  مصدر الكتاب : موقع نداء الايمان\n[موقع نداء ال...  [BOOKS_AND_REFERENCE]
# 858  Kumpulan lagu galau patah hati terbaru 2020 pa...      [MUSIC_AND_AUDIO]
# 861  Dj Remix Offline 2020 Mp3 merupakan aplikasi m...      [MUSIC_AND_AUDIO]
#
#     os_platform lang_code
# 2           IOS     zh-tw
# 7       ANDROID        ko
# 12      ANDROID        id
# 13      ANDROID        th
# 20      ANDROID        id
# ..          ...       ...
# 842     ANDROID        id
# 854     ANDROID        vi
# 855     ANDROID        ar
# 858     ANDROID        id
# 861     ANDROID        id
#
# [179 rows x 6 columns]

# %% [markdown]
# ## Building LDA model - topic modelling from below
# ### Using only EN partion of data

# %%
# Building LDA model
df_parquet_en = df_parquet_pd.loc[df_parquet_pd['lang_code']=='en']
df_parquet_en.shape
# Out:
# (686, 6)

# %%
df_spark = spark.createDataFrame(df_parquet_en)

# %%
# df_parquet=df_parquet.drop("description_token")
df_spark.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+
# |            app_name|              bundle|         description|              genres|os_platform|lang_code|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+
# |Black Box - Movie...|           958957112|Black Box Movie L...|[Entertainment, M...|        IOS|       en|
# |  Knife Throwing Max|          1491396285|you will have fun...|[Games_Sports, Ga...|        IOS|       en|
# |Lidow - Photo Edi...|           894532288|layout/grid/colla...|     [Photo & Video]|        IOS|       en|
# |Vidstitch Frames ...|           712908978|■ #Vidstitch
# ■ Fe...|[Photo & Video, S...|        IOS|       en|
# |Where's my Cat? -...|          1259238703|The cat is hiding...|[Entertainment, G...|        IOS|       en|
# |Martial Art Wallp...|com.martialart.wa...|Martial arts are ...|   [PERSONALIZATION]|    ANDROID|       en|
# |      Image detector|com.saryelgmal.se...|Google image sear...|             [TOOLS]|    ANDROID|       en|
# |Horoscope - Face ...|com.ocean.horosco...|Your face reveals...|         [LIFESTYLE]|    ANDROID|       en|
# |Neon Pastel Heart...|com.ikeyboard.the...|💌
# Neon Pastel He...|   [PERSONALIZATION]|    ANDROID|       en|
# |Arabic Voice Typi...|com.worthy.apps.a...|⭕ Arabic Voice Ke...|             [TOOLS]|    ANDROID|       en|
# |Document Scanner ...|   com.cv.docscanner|Sometimes in a si...|      [PRODUCTIVITY]|    ANDROID|       en|
# |Vob To Mp4 Video ...|    grant.vob.to.mp4|Easy to use tool ...|     [VIDEO_PLAYERS]|    ANDROID|       en|
# |satfinder, Tv Sat...|com.afnan.satfind...|Finding a TV sate...|             [TOOLS]|    ANDROID|       en|
# |Chat with sasha &...|   com.sasha.maxchat|If you are a grea...|   [GAME_SIMULATION]|    ANDROID|       en|
# |             Chess 2|com.onecwireless....|Play new, easy to...|        [GAME_BOARD]|    ANDROID|       en|
# |Merge Airplane Id...|com.pf.idleplane....|Click, merge & de...|   [GAME_SIMULATION]|    ANDROID|       en|
# |Date-me - Free Da...|  com.dateme.android|Date-me gets you ...|            [SOCIAL]|    ANDROID|       en|
# |Software Engineering|com.faadooenginee...|The app is a comp...|         [EDUCATION]|    ANDROID|       en|
# |Multi FB - Multi ...|multiple.accounts...|Want to login mul...|            [SOCIAL]|    ANDROID|       en|
# |Walktrough: Resid...|com.guideforresid...|Informations, Tip...|         [EDUCATION]|    ANDROID|       en|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+
# only showing top 20 rows

# %% [markdown]
# ## For each description, it is treated as a seperate document, and apply LDA model on it, and extract top 3 topics

# %%
# Step 1. Text cleasing with punctuations
from pyspark.sql.functions import regexp_replace
REGEX = '[,\\-.!?@#$%^&*+/]'
df_spark = df_spark.withColumn("description_clean",regexp_replace(df_spark.description,REGEX,' '))
df_spark.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+
# |            app_name|              bundle|         description|              genres|os_platform|lang_code|   description_clean|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+
# |Black Box - Movie...|           958957112|Black Box Movie L...|[Entertainment, M...|        IOS|       en|Black Box Movie L...|
# |  Knife Throwing Max|          1491396285|you will have fun...|[Games_Sports, Ga...|        IOS|       en|you will have fun...|
# |Lidow - Photo Edi...|           894532288|layout/grid/colla...|     [Photo & Video]|        IOS|       en|layout grid colla...|
# |Vidstitch Frames ...|           712908978|■ #Vidstitch
# ■ Fe...|[Photo & Video, S...|        IOS|       en|■  Vidstitch
# ■ Fe...|
# |Where's my Cat? -...|          1259238703|The cat is hiding...|[Entertainment, G...|        IOS|       en|The cat is hiding...|
# |Martial Art Wallp...|com.martialart.wa...|Martial arts are ...|   [PERSONALIZATION]|    ANDROID|       en|Martial arts are ...|
# |      Image detector|com.saryelgmal.se...|Google image sear...|             [TOOLS]|    ANDROID|       en|Google image sear...|
# |Horoscope - Face ...|com.ocean.horosco...|Your face reveals...|         [LIFESTYLE]|    ANDROID|       en|Your face reveals...|
# |Neon Pastel Heart...|com.ikeyboard.the...|💌
# Neon Pastel He...|   [PERSONALIZATION]|    ANDROID|       en|💌
# Neon Pastel He...|
# |Arabic Voice Typi...|com.worthy.apps.a...|⭕ Arabic Voice Ke...|             [TOOLS]|    ANDROID|       en|⭕ Arabic Voice Ke...|
# |Document Scanner ...|   com.cv.docscanner|Sometimes in a si...|      [PRODUCTIVITY]|    ANDROID|       en|Sometimes in a si...|
# |Vob To Mp4 Video ...|    grant.vob.to.mp4|Easy to use tool ...|     [VIDEO_PLAYERS]|    ANDROID|       en|Easy to use tool ...|
# |satfinder, Tv Sat...|com.afnan.satfind...|Finding a TV sate...|             [TOOLS]|    ANDROID|       en|Finding a TV sate...|
# |Chat with sasha &...|   com.sasha.maxchat|If you are a grea...|   [GAME_SIMULATION]|    ANDROID|       en|If you are a grea...|
# |             Chess 2|com.onecwireless....|Play new, easy to...|        [GAME_BOARD]|    ANDROID|       en|Play new  easy to...|
# |Merge Airplane Id...|com.pf.idleplane....|Click, merge & de...|   [GAME_SIMULATION]|    ANDROID|       en|Click  merge   de...|
# |Date-me - Free Da...|  com.dateme.android|Date-me gets you ...|            [SOCIAL]|    ANDROID|       en|Date me gets you ...|
# |Software Engineering|com.faadooenginee...|The app is a comp...|         [EDUCATION]|    ANDROID|       en|The app is a comp...|
# |Multi FB - Multi ...|multiple.accounts...|Want to login mul...|            [SOCIAL]|    ANDROID|       en|Want to login mul...|
# |Walktrough: Resid...|com.guideforresid...|Informations, Tip...|         [EDUCATION]|    ANDROID|       en|Informations  Tip...|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+
# only showing top 20 rows

# %%
# Step 2. Tokenization
from pyspark.ml.feature import Tokenizer
tokenizer = Tokenizer(inputCol='description_clean',outputCol='description_token')
df_spark = tokenizer.transform(df_spark)
df_spark.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+
# |            app_name|              bundle|         description|              genres|os_platform|lang_code|   description_clean|   description_token|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+
# |Black Box - Movie...|           958957112|Black Box Movie L...|[Entertainment, M...|        IOS|       en|Black Box Movie L...|[black, box, movi...|
# |  Knife Throwing Max|          1491396285|you will have fun...|[Games_Sports, Ga...|        IOS|       en|you will have fun...|[you, will, have,...|
# |Lidow - Photo Edi...|           894532288|layout/grid/colla...|     [Photo & Video]|        IOS|       en|layout grid colla...|[layout, grid, co...|
# |Vidstitch Frames ...|           712908978|■ #Vidstitch
# ■ Fe...|[Photo & Video, S...|        IOS|       en|■  Vidstitch
# ■ Fe...|[■, , vidstitch, ...|
# |Where's my Cat? -...|          1259238703|The cat is hiding...|[Entertainment, G...|        IOS|       en|The cat is hiding...|[the, cat, is, hi...|
# |Martial Art Wallp...|com.martialart.wa...|Martial arts are ...|   [PERSONALIZATION]|    ANDROID|       en|Martial arts are ...|[martial, arts, a...|
# |      Image detector|com.saryelgmal.se...|Google image sear...|             [TOOLS]|    ANDROID|       en|Google image sear...|[google, image, s...|
# |Horoscope - Face ...|com.ocean.horosco...|Your face reveals...|         [LIFESTYLE]|    ANDROID|       en|Your face reveals...|[your, face, reve...|
# |Neon Pastel Heart...|com.ikeyboard.the...|💌
# Neon Pastel He...|   [PERSONALIZATION]|    ANDROID|       en|💌
# Neon Pastel He...|[💌, neon, pastel...|
# |Arabic Voice Typi...|com.worthy.apps.a...|⭕ Arabic Voice Ke...|             [TOOLS]|    ANDROID|       en|⭕ Arabic Voice Ke...|[⭕, arabic, voice...|
# |Document Scanner ...|   com.cv.docscanner|Sometimes in a si...|      [PRODUCTIVITY]|    ANDROID|       en|Sometimes in a si...|[sometimes, in, a...|
# |Vob To Mp4 Video ...|    grant.vob.to.mp4|Easy to use tool ...|     [VIDEO_PLAYERS]|    ANDROID|       en|Easy to use tool ...|[easy, to, use, t...|
# |satfinder, Tv Sat...|com.afnan.satfind...|Finding a TV sate...|             [TOOLS]|    ANDROID|       en|Finding a TV sate...|[finding, a, tv, ...|
# |Chat with sasha &...|   com.sasha.maxchat|If you are a grea...|   [GAME_SIMULATION]|    ANDROID|       en|If you are a grea...|[if, you, are, a,...|
# |             Chess 2|com.onecwireless....|Play new, easy to...|        [GAME_BOARD]|    ANDROID|       en|Play new  easy to...|[play, new, , eas...|
# |Merge Airplane Id...|com.pf.idleplane....|Click, merge & de...|   [GAME_SIMULATION]|    ANDROID|       en|Click  merge   de...|[click, , merge, ...|
# |Date-me - Free Da...|  com.dateme.android|Date-me gets you ...|            [SOCIAL]|    ANDROID|       en|Date me gets you ...|[date, me, gets, ...|
# |Software Engineering|com.faadooenginee...|The app is a comp...|         [EDUCATION]|    ANDROID|       en|The app is a comp...|[the, app, is, a,...|
# |Multi FB - Multi ...|multiple.accounts...|Want to login mul...|            [SOCIAL]|    ANDROID|       en|Want to login mul...|[want, to, login,...|
# |Walktrough: Resid...|com.guideforresid...|Informations, Tip...|         [EDUCATION]|    ANDROID|       en|Informations  Tip...|[informations, , ...|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Step 3. Remove stopword
from pyspark.ml.feature import StopWordsRemover
stopwords = StopWordsRemover(inputCol="description_token",outputCol="description_no_stop")
# stopwords.getStopWords()
df_spark = stopwords.transform(df_spark)
df_spark.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+--------------------+
# |            app_name|              bundle|         description|              genres|os_platform|lang_code|   description_clean|   description_token| description_no_stop|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+--------------------+
# |Black Box - Movie...|           958957112|Black Box Movie L...|[Entertainment, M...|        IOS|       en|Black Box Movie L...|[black, box, movi...|[black, box, movi...|
# |  Knife Throwing Max|          1491396285|you will have fun...|[Games_Sports, Ga...|        IOS|       en|you will have fun...|[you, will, have,...|[fun, game, 100, ...|
# |Lidow - Photo Edi...|           894532288|layout/grid/colla...|     [Photo & Video]|        IOS|       en|layout grid colla...|[layout, grid, co...|[layout, grid, co...|
# |Vidstitch Frames ...|           712908978|■ #Vidstitch
# ■ Fe...|[Photo & Video, S...|        IOS|       en|■  Vidstitch
# ■ Fe...|[■, , vidstitch, ...|[■, , vidstitch, ...|
# |Where's my Cat? -...|          1259238703|The cat is hiding...|[Entertainment, G...|        IOS|       en|The cat is hiding...|[the, cat, is, hi...|[cat, hiding, com...|
# |Martial Art Wallp...|com.martialart.wa...|Martial arts are ...|   [PERSONALIZATION]|    ANDROID|       en|Martial arts are ...|[martial, arts, a...|[martial, arts, c...|
# |      Image detector|com.saryelgmal.se...|Google image sear...|             [TOOLS]|    ANDROID|       en|Google image sear...|[google, image, s...|[google, image, s...|
# |Horoscope - Face ...|com.ocean.horosco...|Your face reveals...|         [LIFESTYLE]|    ANDROID|       en|Your face reveals...|[your, face, reve...|[face, reveals, l...|
# |Neon Pastel Heart...|com.ikeyboard.the...|💌
# Neon Pastel He...|   [PERSONALIZATION]|    ANDROID|       en|💌
# Neon Pastel He...|[💌, neon, pastel...|[💌, neon, pastel...|
# |Arabic Voice Typi...|com.worthy.apps.a...|⭕ Arabic Voice Ke...|             [TOOLS]|    ANDROID|       en|⭕ Arabic Voice Ke...|[⭕, arabic, voice...|[⭕, arabic, voice...|
# |Document Scanner ...|   com.cv.docscanner|Sometimes in a si...|      [PRODUCTIVITY]|    ANDROID|       en|Sometimes in a si...|[sometimes, in, a...|[sometimes, singl...|
# |Vob To Mp4 Video ...|    grant.vob.to.mp4|Easy to use tool ...|     [VIDEO_PLAYERS]|    ANDROID|       en|Easy to use tool ...|[easy, to, use, t...|[easy, use, tool,...|
# |satfinder, Tv Sat...|com.afnan.satfind...|Finding a TV sate...|             [TOOLS]|    ANDROID|       en|Finding a TV sate...|[finding, a, tv, ...|[finding, tv, sat...|
# |Chat with sasha &...|   com.sasha.maxchat|If you are a grea...|   [GAME_SIMULATION]|    ANDROID|       en|If you are a grea...|[if, you, are, a,...|[great, fan, “sas...|
# |             Chess 2|com.onecwireless....|Play new, easy to...|        [GAME_BOARD]|    ANDROID|       en|Play new  easy to...|[play, new, , eas...|[play, new, , eas...|
# |Merge Airplane Id...|com.pf.idleplane....|Click, merge & de...|   [GAME_SIMULATION]|    ANDROID|       en|Click  merge   de...|[click, , merge, ...|[click, , merge, ...|
# |Date-me - Free Da...|  com.dateme.android|Date-me gets you ...|            [SOCIAL]|    ANDROID|       en|Date me gets you ...|[date, me, gets, ...|[date, gets, back...|
# |Software Engineering|com.faadooenginee...|The app is a comp...|         [EDUCATION]|    ANDROID|       en|The app is a comp...|[the, app, is, a,...|[app, complete, f...|
# |Multi FB - Multi ...|multiple.accounts...|Want to login mul...|            [SOCIAL]|    ANDROID|       en|Want to login mul...|[want, to, login,...|[want, login, mul...|
# |Walktrough: Resid...|com.guideforresid...|Informations, Tip...|         [EDUCATION]|    ANDROID|       en|Informations  Tip...|[informations, , ...|[informations, , ...|
# +--------------------+--------------------+--------------------+--------------------+-----------+---------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Iterate each row and build LDA for each one of it
df_pd_desc_final = df_spark.toPandas()

# %%
# TODO
row1 = df_pd_desc_final['description_no_stop'][0]
len(row1)
# Out:
# 326

# %%
# Step 4. TF-IDF countvector, Transform documents to document-term matrix
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df=0.95) #ignore terms that have a document frequency strictly higher than the given threshold
dtm = cv.fit_transform(row1)

# %%
# Step 5. use TF-IDF vector to do LDA model
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=5,random_state=123) #select only top 5 topics
LDA.fit_transform(dtm)
# Out:
# array([[0.10000588, 0.10000713, 0.59997482, 0.10000644, 0.10000573],
#        [0.10000517, 0.59997861, 0.10000551, 0.10000567, 0.10000504],
#        [0.10000371, 0.1000045 , 0.10000395, 0.10000406, 0.59998378],
#        ...,
#        [0.10000926, 0.10001124, 0.59996031, 0.10001015, 0.10000903],
#        [0.59990089, 0.10002764, 0.1000243 , 0.10002497, 0.10002221],
#        [0.10001013, 0.10001229, 0.10001081, 0.10001111, 0.59995566]])

# %%
LDA.components_.shape
# Out:
# (5, 141)

# %%
cv.get_feature_names()
# Out:
# ['22nd',
#  '24',
#  '39',
#  '99',
#  'access',
#  'account',
#  'actors',
#  'actresses',
#  'ad',
#  'add',
#  'advertisement',
#  'aim',
#  'also',
#  'annual',
#  'anytime',
#  'app',
#  'areas',
#  'around',
#  'auto',
#  'automatically',
#  'available',
#  'black',
#  'box',
#  'buy',
#  'casts',
#  'cater',
#  'charged',
#  'choose',
#  'collection',
#  'com',
#  'communities',
#  'conditions',
#  'confirmation',
#  'contains',
#  'content',
#  'cost',
#  'current',
#  'date',
#  'detailed',
#  'details',
#  'different',
#  'director',
#  'diverse',
#  'duration',
#  'end',
#  'etc',
#  'events',
#  'every',
#  'example',
#  'features',
#  'february',
#  'from',
#  'gain',
#  'general',
#  'going',
#  'hours',
#  'http',
#  'https',
#  'identify',
#  'images',
#  'imdb',
#  'information',
#  'informs',
#  'international',
#  'itunes',
#  'later',
#  'least',
#  'list',
#  'listing',
#  'local',
#  'make',
#  'manage',
#  'media',
#  'month',
#  'monthly',
#  'movie',
#  'movies',
#  'my',
#  'newly',
#  'news',
#  'note',
#  'occurring',
#  'offline',
#  'one',
#  'online',
#  'opt',
#  'organize',
#  'payments',
#  'period',
#  'php',
#  'platforms',
#  'plays',
#  'policy',
#  'popular',
#  'population',
#  'posters',
#  'postings',
#  'premium',
#  'prior',
#  'privacy',
#  'pulls',
#  'purchase',
#  'purchases',
#  'reign',
#  'release',
#  'released',
#  'removal',
#  'removes',
#  'renew',
#  'renewal',
#  'renews',
#  'section',
#  'settings',
#  'share',
#  'show',
#  'shows',
#  'simple',
#  'social',
#  'specific',
#  'stay',
#  'studio',
#  'subscription',
#  'subscriptions',
#  'terms',
#  'trailer',
#  'turned',
#  'turning',
#  'tv',
#  'unless',
#  'usd',
#  'use',
#  'user',
#  'users',
#  'video',
#  'view',
#  'watch',
#  'way',
#  'website',
#  'wish',
#  'within',
#  'world']

# %%
topic.argsort()[-5:]
# Out:
# array([127,  22, 129,  18, 103, 134,  61,  92,  67,   5,  15,  79, 109,
#          8,  73,  21, 101, 111,  76,  36,  41,  17,  72, 123,   4,   0,
#         44,   1, 135, 114,  59,  45,  47, 105, 131,  63,  11, 137,   6,
#        139, 117, 128,  49, 119,  56,  84,  69,   3, 132, 122, 115,  28,
#         46,  55, 140,  90,  50,  97,  87,  78,  65, 136,  39,  85,  70,
#         38, 124,  91,   9, 102,  77, 112,  80,  60, 133,  43, 138, 118,
#         82,  86,  34,  53,  64,  16,   7, 116,  57,  62,  48,  23, 108,
#         35,  98,  51,  37,  66,  10, 113, 110,  27, 130,  58,  30,  13,
#         14,  19,  95,  31,  24,  94, 126,  52, 107,  93,  33,  25,  96,
#         81, 104,  12,  54, 120,  32, 100, 125,   2,  74,  20,  40,  71,
#         68,  42,  29,  89,  99,  88,  26, 106,  83,  75, 121], dtype=int64)

# %%
for index,topic in enumerate(LDA.components_):
    print(f'Keywords for Topic #{index+1}')
    keyword = [cv.get_feature_names()[i] for i in topic.argsort()[-5:]]
    print(keyword)
# Out:
# Keywords for Topic #1
# ['subscriptions', 'users', '99', 'media', 'movies']
# Keywords for Topic #2
# ['reign', 'auto', 'usd', 'box', 'tv']
# Keywords for Topic #3
# ['section', 'purchase', 'black', 'news', 'app']
# Keywords for Topic #4
# ['month', 'renewal', 'ad', 'account', 'list']
# Keywords for Topic #5
# ['charged', 'removal', 'one', 'movie', 'subscription']

# %%
# Step 6. Combine result back to dataset. Insert the result into three sepearate columns.

# %% [markdown]
# ## Build Text cleaning pipeline

# %% [markdown]
# ## Convert Pandas DataFrame to Spark DataFrame

# %%
df_parquet = spark.createDataFrame(df_parquet_pd)

# %%
spark_df
# Out:
# DataFrame[app_name: string, bundle: string, description: string, genres: array<string>, os_platform: string, lang_code: string]
